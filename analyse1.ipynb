# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"TEST1.CSV", encoding = "ISO-8859-1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   $Date              99 non-null     object
#  1   $Time              99 non-null     object
#  2   PÅDRAG             99 non-null     int64
#  3   REF                99 non-null     int64
#  4   TANKLEVEL          98 non-null     float64
#  5   TANKLEVELFILTERED  98 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ KB

# %%
t = df['$Time']
y = df['TANKLEVEL']
yf = df['TANKLEVELFILTERED']

plt.plot(t, y, yf)
